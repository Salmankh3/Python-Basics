# %% [markdown]
# # 17th November 2019

# %% [markdown]
# # OLD PRACTISE

# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("C:/Users/hp/Desktop/Book1.csv")
a
# Out:
#       Name        F.name  Roll Number      Course  Location
# 0   Salman   Abdul Rahim           15          AI   Gulshan
# 1   Nabeel       M.Iqbal           11       Cloud       NaN
# 2    Uzaif  Bashir Ahmed           20  Blockchain  Baghdadi
# 3   Raheel          Umer           18          AI   Gulshan
# 4  Sameer         Saleem           16  Blockchain   Gulshan
# 5    Zafar         Hayat           25       Cloud    Kemari

# %%
a["Roll Number"].mean()
# Out:
# 17.5

# %%
a["Course"]=="AI"
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: Course, dtype: bool

# %%
a[a["Course"]=="AI"]
# Out:
#      Name       F.name  Roll Number Course Location
# 0  Salman  Abdul Rahim           15     AI  Gulshan
# 3  Raheel         Umer           18     AI  Gulshan

# %%
a[(a["Course"]=="AI") & (a["Location"]=="Gulshan")]
# Out:
#      Name       F.name  Roll Number Course Location
# 0  Salman  Abdul Rahim           15     AI  Gulshan
# 3  Raheel         Umer           18     AI  Gulshan

# %%
a[(a["Course"]=="AI") | (a["Name"]=="Uzaif")]
# Out:
#      Name        F.name  Roll Number      Course  Location
# 0  Salman   Abdul Rahim           15          AI   Gulshan
# 2   Uzaif  Bashir Ahmed           20  Blockchain  Baghdadi
# 3  Raheel          Umer           18          AI   Gulshan

# %% [markdown]
# # DATA CLEANING AND PREPARATION

# %% [markdown]
# Data is cleaned due to:
#
# - Anomaly / Outlayer Values
# - Missing Values
# - Non-meaningful Headings

# %% [markdown]
# We need preparation of Data when:
# - Duplicate Values are deleted in preparing
# - Combining Datasets from different places

# %%
a.isnull()
# Out:
#     Name  F.name  Roll Number  Course  Location
# 0  False   False        False   False     False
# 1  False   False        False   False      True
# 2  False   False        False   False     False
# 3  False   False        False   False     False
# 4  False   False        False   False     False
# 5  False   False        False   False     False

# %%
a.dropna()
# Out:
#       Name        F.name  Roll Number      Course  Location
# 0   Salman   Abdul Rahim           15          AI   Gulshan
# 2    Uzaif  Bashir Ahmed           20  Blockchain  Baghdadi
# 3   Raheel          Umer           18          AI   Gulshan
# 4  Sameer         Saleem           16  Blockchain   Gulshan
# 5    Zafar         Hayat           25       Cloud    Kemari

# %%
a2 = a.dropna()
a2
# Out:
#       Name        F.name  Roll Number      Course  Location
# 0   Salman   Abdul Rahim           15          AI   Gulshan
# 2    Uzaif  Bashir Ahmed           20  Blockchain  Baghdadi
# 3   Raheel          Umer           18          AI   Gulshan
# 4  Sameer         Saleem           16  Blockchain   Gulshan
# 5    Zafar         Hayat           25       Cloud    Kemari

# %%
a3 = a.dropna(how="all") #how=all delets the rows having all the values as NaN, if not all are Nan, it donot delete the row
a3
# Out:
#       Name        F.name  Roll Number      Course  Location
# 0   Salman   Abdul Rahim           15          AI   Gulshan
# 1   Nabeel       M.Iqbal           11       Cloud       NaN
# 2    Uzaif  Bashir Ahmed           20  Blockchain  Baghdadi
# 3   Raheel          Umer           18          AI   Gulshan
# 4  Sameer         Saleem           16  Blockchain   Gulshan
# 5    Zafar         Hayat           25       Cloud    Kemari

# %% [markdown]
# axis = 1 works in columns

# %%
a3.dropna(axis=1)
# Out:
#       Name        F.name  Roll Number      Course
# 0   Salman   Abdul Rahim           15          AI
# 1   Nabeel       M.Iqbal           11       Cloud
# 2    Uzaif  Bashir Ahmed           20  Blockchain
# 3   Raheel          Umer           18          AI
# 4  Sameer         Saleem           16  Blockchain
# 5    Zafar         Hayat           25       Cloud

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df
# Out:
#           0         1         2
# 0  1.145752  0.612570  1.620883
# 1  0.249189 -0.581425 -0.908025
# 2  0.263650  0.709139 -0.534638
# 3 -0.548789 -0.781703  2.146843
# 4  1.465882 -1.492502  0.486375
# 5 -1.081045  1.445597 -0.880568
# 6 -0.213008  1.491305  0.794369

# %%
df.iloc[:4, 2] = 0
df
# Out:
#           0         1         2
# 0  1.145752  0.612570         0
# 1  0.249189 -0.581425         0
# 2  0.263650  0.709139         0
# 3 -0.548789 -0.781703         0
# 4  1.465882 -1.492502  0.486375
# 5 -1.081045  1.445597 -0.880568
# 6 -0.213008  1.491305  0.794369

# %%
df.fillna("null")
df
# Out:
#           0         1         2
# 0  1.145752  0.612570         0
# 1  0.249189 -0.581425         0
# 2  0.263650  0.709139         0
# 3 -0.548789 -0.781703         0
# 4  1.465882 -1.492502  0.486375
# 5 -1.081045  1.445597 -0.880568
# 6 -0.213008  1.491305  0.794369

# %%
a.fillna("Leemarket") #fills the given value at NaN
# Out:
#       Name        F.name  Roll Number      Course   Location
# 0   Salman   Abdul Rahim           15          AI    Gulshan
# 1   Nabeel       M.Iqbal           11       Cloud  Leemarket
# 2    Uzaif  Bashir Ahmed           20  Blockchain   Baghdadi
# 3   Raheel          Umer           18          AI    Gulshan
# 4  Sameer         Saleem           16  Blockchain    Gulshan
# 5    Zafar         Hayat           25       Cloud     Kemari

# %%
df.dropna(thresh=#number) #Delete Number of rows having NaN, that are given @ #number)

# %%
data = {"Student":["Kamal","Jamal","Rumaal","Khayal","Dayaal"],
       "Course":["AI",np.NaN,np.NaN,np.NaN,np.NaN],
       "Roll No":[11,12,14,5,np.NaN]}
df2 = pd.DataFrame(data)
df2
# Out:
#   Student Course  Roll No
# 0   Kamal     AI     11.0
# 1   Jamal    NaN     12.0
# 2  Rumaal    NaN     14.0
# 3  Khayal    NaN      5.0
# 4  Dayaal    NaN      NaN

# %%
df2.

# %%
df2.fillna(method="ffill")
# Out:
#   Student Course  Roll No
# 0   Kamal     AI     11.0
# 1   Jamal     AI     12.0
# 2  Rumaal     AI     14.0
# 3  Khayal     AI      5.0
# 4  Dayaal     AI      5.0
